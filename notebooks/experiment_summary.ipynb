# %% [markdown]
# # Tóm tắt thực nghiệm dự đoán giá nhà
#
# Notebook này dùng để trình bày lại kết quả đã sinh bởi `main.py`, không lặp lại toàn bộ logic huấn luyện.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import pandas as pd
from IPython.display import Image, display
from src import config

# %% [markdown]
# ## Bảng so sánh mô hình
#
# Metrics được tính trên giá gốc sau khi inverse log-transform bằng `np.expm1`.

# %%
comparison_path = config.MODEL_COMPARISON_PATH
comparison_df = pd.read_csv(comparison_path)
comparison_df

# %% [markdown]
# ## Biểu đồ loss của từng mô hình

# %%
for name in ['loss_ann_baseline.png', 'loss_ft_transformer_lite.png', 'loss_adaptive_ann.png']:
    path = config.FIGURE_DIR / name
    if path.exists():
        display(Image(filename=str(path)))

# %% [markdown]
# ## Biểu đồ so sánh metrics

# %%
display(Image(filename=str(config.FIGURE_DIR / 'metrics_comparison.png')))

# %% [markdown]
# ## Giá thực tế và giá dự đoán của model tốt nhất

# %%
display(Image(filename=str(config.FIGURE_DIR / 'actual_vs_predicted_best_model.png')))
display(Image(filename=str(config.FIGURE_DIR / 'residual_plot_best_model.png')))

# %% [markdown]
# ## Nhận xét ngắn
#
# Dựa trên `model_comparison.csv`, chọn model tốt nhất theo MAE hoặc RMSE. Không kết luận mô hình đề xuất vượt trội nếu metrics không chứng minh rõ.
